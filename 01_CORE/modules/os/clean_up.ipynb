# %%
import sys, os
print("Python is looking here:")

for p in sys.path:
    print(p)
# Out:
# Python is looking here:
# C:\Users\Dell\Desktop\My-Modules
# c:\Users\Dell\anaconda3\envs\ds-ml\python311.zip
# c:\Users\Dell\anaconda3\envs\ds-ml\DLLs
# c:\Users\Dell\anaconda3\envs\ds-ml\Lib
# c:\Users\Dell\anaconda3\envs\ds-ml
#
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages
# c:\Users\Dell\anaconda3\envs\ds-ml\Lib\site-packages

# %%
import pathlib
print(pathlib.__file__)   # This should pioint to your python install, not your folder
from pathlib import Path
print(Path.cwd())
# Out:
# c:\Users\Dell\anaconda3\envs\ds-ml\Lib\pathlib.py
# c:\Users\Dell\Documents\MY_WORKSPACE\01_SKILLS\04_PYTHON_MASTERY\03_SOFTWARE_&_SYSTEMS\pathlib_os

# %%
p = Path(__file__).cwd()
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p = Path(__file__).cwd()
#       2 print(p)
#
# NameError: name '__file__' is not defined

# %%
import os

print("Current working directory:", os.getcwd())

import pathlib
print("Pathlib location:", pathlib.__file__)
# Out:
# Current working directory: c:\Users\Dell\Documents\MY_WORKSPACE\01_SKILLS\04_PYTHON_MASTERY\03_SOFTWARE_&_SYSTEMS\pathlib_os
# Pathlib location: c:\Users\Dell\anaconda3\envs\ds-ml\Lib\pathlib.py

# %%
from pathlib import Path
print("It work!", Path.cwd())
# Out:
# It work! c:\Users\Dell\Documents\MY_WORKSPACE\01_SKILLS\04_PYTHON_MASTERY\03_SOFTWARE_&_SYSTEMS\pathlib_os
