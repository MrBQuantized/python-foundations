# %% [markdown]
# # DSA — Sorting
# ---
#
# > ## Learn Important Sorting Techniques

# %% [markdown]
# Sorting
# Easy Selection Sort
# Easy Bubble Sort
# Easy Insertion Sort
# Medium Merge Sort
# Easy Recursive Bubble Sort
# Easy Recursive Insertio
