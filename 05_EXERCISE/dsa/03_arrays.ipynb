# %% [markdown]
# # DSA — ARRAYS
# ---
#
# > ## Solve Problems on Arrays Easy → Medium → Hard

# %% [markdown]
# ## Easy

# %% [markdown]
# ### Largest Element in an Array

# %% [markdown]
# Easy Second Largest Element in an Array Without Sorting
# Easy Check if the Array is Sorted
# Easy Remove Duplicates from Sorted Array
# Easy Left Rotate an Array by One Place
# Easy Left Rotate an Array by D Places
# Easy Move Zeros to End
# Easy Linear Search
# Easy Find the Union of Two Sorted Arrays
# Easy Find Missing Number in an Array
# Easy Maximum Consecutive Ones
# Easy Find the Number That Appears Once Others Twice)
# Medium Longest Subarray with Sum K Positives and Negatives)
# Medium Sort an Array of 0s, 1s, and 2s
# Medium Majority Element (> N/2 Times)
# Medium Kadane's Algorithm - Maximum Subarray Sum
# Medium Print Subarray with Maximum Subarray Sum
# Easy Stock Buy and Sell
# Medium Rearrange Array Elements by Sign
# Medium Next Permutation
# Easy Leaders in an Array
# Medium Longest Consecutive Sequence in an Array
# Medium Set Matrix Zeros
# Medium Rotate Matrix by 90 Degrees
# Medium Spiral Traversal of Matrix
# Medium Count Subarrays with Given Sum
# Medium Pascal's Triangle
# Medium Majority Element N/3 Times)
# Medium 3Sum Problem
# Hard 4Sum Problem
# Medium Largest Subarray with 0 Sum
# Hard Count Number of Subarrays with XOR  K
# Medium Merge Overlapping Subintervals
# Hard Merge Two Sorted Arrays Without Extra Space
# Hard Find the Repeating and Missing Numbers
# Hard Count Inversions
# Hard Reverse Pairs
# Medium Maximum Product Subarray
# Medium Grid Unique Paths
# Hard Find the Missing and Repeating Using Maths)
